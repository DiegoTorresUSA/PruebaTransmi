# %%
import pandas as pd

# %%
my_df = pd.read_excel('PSO20220223.xls')

# %%
my_df.head(2)
# Out:
#               NODO_1          NODO_2  DISTANCIA TIPODIA HORA_DESDE HORA_HASTA  \
# 0  Patio 20 de Julio  Patio Eldorado      18669   Habil   00:00:00   40:00:00
# 1  Patio 20 de Julio      Patio Suba      25397   Habil   00:00:00   40:00:00
#
#   TR_OPTIMO TR_MINIMO TR_MAXIMO
# 0  00:45:30  00:44:30  00:49:00
# 1  01:06:30  01:05:15  01:11:45

# %%
my_df.groupby(['linea']).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 my_df.groupby(['linea']).count()
#
# File c:\lenovo\mision tic2022\python\pythonlibro\venv\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
#    7721     observed=observed,
# ...

# %%
my_df.groupby(['NODO_1']).count()
# Out:
#                          NODO_2  DISTANCIA  TIPODIA  HORA_DESDE  HORA_HASTA  \
# NODO_1
# Aguas A - 1                 187        187      187         187         187
# Aguas A - 2 ó 5             187        187      187         187         187
# Alcalá A - 2 ó 5            187        187      187         187         187
# Alcalá A - 4 ó 6            187        187      187         187         187
# Alcalá B - 4 ó 6            187        187      187         187         187
# ...                         ...        ...      ...         ...         ...
# Tv. 86 B - 2 ó 5            261        261      261         261         261
# Universidades A - 2 ó 5     187        187      187         187         187
# Universidades A - 4 ó 6     187        187      187         187         187
# Universidades B - 2 ó 5     187        187      187         187         187
# Universidades B - 4 ó 6     187        187      187         187         187
#
# ...

# %%
my_df.groupby(['sentido']).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 my_df.groupby(['sentido']).count()
#
# File c:\lenovo\mision tic2022\python\pythonlibro\venv\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
#    7721     observed=observed,
# ...

# %%
my_df.head(2)
# Out:
#               NODO_1          NODO_2  DISTANCIA TIPODIA HORA_DESDE HORA_HASTA  \
# 0  Patio 20 de Julio  Patio Eldorado      18669   Habil   00:00:00   40:00:00
# 1  Patio 20 de Julio      Patio Suba      25397   Habil   00:00:00   40:00:00
#
#   TR_OPTIMO TR_MINIMO TR_MAXIMO
# 0  00:45:30  00:44:30  00:49:00
# 1  01:06:30  01:05:15  01:11:45

# %%
my_df.groupby(['linea'].size().reset_index(name='Prueba'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 my_df.groupby(['linea'].size().reset_index(name='Prueba'))
#
# AttributeError: 'list' object has no attribute 'size'

# %%
my_df.groupby(['linea'].count().reset_index(name='Prueba'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 my_df.groupby(['linea'].count().reset_index(name='Prueba'))
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
my_df.groupby(['linea'].count()
# Out:
#   Input In [10]
#     my_df.groupby(['linea'].count()
#                                    ^
# SyntaxError: incomplete input

# %%
g = my_df.groupby('linea')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 g = my_df.groupby('linea')
#
# File c:\lenovo\mision tic2022\python\pythonlibro\venv\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
#    7721     observed=observed,
# ...

# %%
my_df = pd.read_excel('PSO20220223.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 my_df = pd.read_excel('PSO20220223.csv')
#
# File c:\lenovo\mision tic2022\python\pythonlibro\venv\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
my_df.head(2)
# Out:
#               NODO_1          NODO_2  DISTANCIA TIPODIA HORA_DESDE HORA_HASTA  \
# 0  Patio 20 de Julio  Patio Eldorado      18669   Habil   00:00:00   40:00:00
# 1  Patio 20 de Julio      Patio Suba      25397   Habil   00:00:00   40:00:00
#
#   TR_OPTIMO TR_MINIMO TR_MAXIMO
# 0  00:45:30  00:44:30  00:49:00
# 1  01:06:30  01:05:15  01:11:45

# %%
g = my_df.groupby('nodo_2')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 g = my_df.groupby('nodo_2')
#
# File c:\lenovo\mision tic2022\python\pythonlibro\venv\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
#    7721     observed=observed,
# ...

# %%
g = my_df.groupby('NODO_2').count()

# %%
my_df.groupby('NODO_2').count()
# Out:
#                          NODO_1  DISTANCIA  TIPODIA  HORA_DESDE  HORA_HASTA  \
# NODO_2
# Aguas A - 1                 187        187      187         187         187
# Aguas A - 2 ó 5             187        187      187         187         187
# Alcalá A - 2 ó 5            187        187      187         187         187
# Alcalá A - 4 ó 6            187        187      187         187         187
# Alcalá B - 4 ó 6            187        187      187         187         187
# ...                         ...        ...      ...         ...         ...
# Tv. 86 B - 2 ó 5            263        263      263         263         263
# Universidades A - 2 ó 5     187        187      187         187         187
# Universidades A - 4 ó 6     187        187      187         187         187
# Universidades B - 2 ó 5     187        187      187         187         187
# Universidades B - 4 ó 6     187        187      187         187         187
#
# ...

# %%
my_df.head(2)
# Out:
#               NODO_1          NODO_2  DISTANCIA TIPODIA HORA_DESDE HORA_HASTA  \
# 0  Patio 20 de Julio  Patio Eldorado      18669   Habil   00:00:00   40:00:00
# 1  Patio 20 de Julio      Patio Suba      25397   Habil   00:00:00   40:00:00
#
#   TR_OPTIMO TR_MINIMO TR_MAXIMO
# 0  00:45:30  00:44:30  00:49:00
# 1  01:06:30  01:05:15  01:11:45

# %%
my_df = pd.read_excel('Prueba1.xlsx')

# %%
my_df.head(2)
# Out:
#    linea         nodo_1            nodo_2  distancia descripcion tipodia  \
# 0      2  Portal Sur T6  Flores B - 4 ó 6      20688  A52 Flores   Habil
# 1      2  Portal Sur T6  Flores B - 4 ó 6      20688  A52 Flores   Habil
#
#   hora_desde hora_hasta tr_optimo tr_minimo tr_maximo  trayecto  sentido  \
# 0   01:00:00   05:30:00  00:54:45  00:51:45  00:56:45      1453        1
# 1   05:30:00   06:30:00  01:00:30  00:56:45  01:03:30      1453        1
#
#    secuencia  tipo_arco
# 0          1          1
# 1          1          1

# %%
my_df.groupby('Nlinea').count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 my_df.groupby('Nlinea').count()
#
# File c:\lenovo\mision tic2022\python\pythonlibro\venv\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
#    7721     observed=observed,
# ...

# %%
my_df.groupby('linea').count()
# Out:
#        nodo_1  nodo_2  distancia  descripcion  tipodia  hora_desde  \
# linea
# 1         100     100        100          100      100         100
# 2          20      20         20           20       20          20
# 4          10      10         10           10       10          10
# 6          30      30         30           30       30          30
# 7          50      50         50           50       50          50
# 8          40      40         40           40       40          40
# 9          50      50         50           50       50          50
# 10         30      30         30           30       30          30
# 11         20      20         20           20       20          20
# 12         50      50         50           50       50          50
# 14         20      20         20           20       20          20
# 15         10      10         10           10       10          10
# 18         10      10         10           10       10          10
# ...

# %%
my_df.groupby('linea').count()
# Out:
#        nodo_1  nodo_2  distancia  descripcion  tipodia  hora_desde  \
# linea
# 1         100     100        100          100      100         100
# 2          20      20         20           20       20          20
# 4          10      10         10           10       10          10
# 6          30      30         30           30       30          30
# 7          50      50         50           50       50          50
# 8          40      40         40           40       40          40
# 9          50      50         50           50       50          50
# 10         30      30         30           30       30          30
# 11         20      20         20           20       20          20
# 12         50      50         50           50       50          50
# 14         20      20         20           20       20          20
# 15         10      10         10           10       10          10
# 18         10      10         10           10       10          10
# ...

# %%
col_max = my_df.max(axis=0)
col_max
# Out:
# C:\Users\MANDO\AppData\Local\Temp\ipykernel_8088\3931392747.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   col_max = my_df.max(axis=0)
# linea                              334
# nodo_1         Universidades B - 4 ó 6
# nodo_2         Universidades B - 2 ó 5
# distancia                        32901
# descripcion         M51 MUSEO NACIONAL
# tipodia                          Habil
# hora_hasta                    30:00:00
# tr_optimo                      1:26:23
# tr_minimo                      1:19:45
# tr_maximo                      1:33:32
# trayecto                          1524
# sentido                              2
# secuencia                            3
# tipo_arco                            1
# dtype: object

# %%
col_max = df['tr_maximo'].max(axis=0)
col_max
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 col_max = df['tr_maximo'].max(axis=0)
#       2 col_max
#
# NameError: name 'df' is not defined

# %%
col_max = my_df['tr_maximo'].max(axis=0)
col_max
# Out:
# '1:33:32'

# %%
my_df.groupby('linea', 'sentido').count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\lenovo\mision tic2022\python\pythonlibro\venv\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 'sentido'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 my_df.groupby('linea', 'sentido', 'tipodia').count()
#
# File c:\lenovo\mision tic2022\python\pythonlibro\venv\lib\site-packages\pandas\core\frame.py:7707, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7705 if level is None and by is None:
#    7706     raise TypeError("You have to supply one of 'by' and 'level'")
# ...

# %%
my_df.groupby('linea', 'sentido').count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\lenovo\mision tic2022\python\pythonlibro\venv\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 'sentido'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 my_df.groupby('linea', 'sentido').count()
#
# File c:\lenovo\mision tic2022\python\pythonlibro\venv\lib\site-packages\pandas\core\frame.py:7707, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7705 if level is None and by is None:
#    7706     raise TypeError("You have to supply one of 'by' and 'level'")
# ...

# %%
my_df.groupby('linea', 'sentido').count(axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\lenovo\mision tic2022\python\pythonlibro\venv\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 'sentido'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 my_df.groupby('linea', 'sentido').count(axis=0)
#
# File c:\lenovo\mision tic2022\python\pythonlibro\venv\lib\site-packages\pandas\core\frame.py:7707, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7705 if level is None and by is None:
#    7706     raise TypeError("You have to supply one of 'by' and 'level'")
# ...

# %%
max_index =my_df.idxmax()
max_index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 max_index =my_df.idxmax()
#       2 max_index
#
# File c:\lenovo\mision tic2022\python\pythonlibro\venv\lib\site-packages\pandas\core\frame.py:10291, in DataFrame.idxmax(self, axis, skipna)
#   10229 """
#   10230 Return index of first occurrence of maximum over requested axis.
#   10231
#    (...)
#   10287 dtype: object
#   10288 """
#   10289 axis = self._get_axis_number(axis)
# > 10291 res = self._reduce(
#   10292     nanops.nanargmax, "argmax", axis=axis, skipna=skipna, numeric_only=False
#   10293 )
#   10294 indices = res._values
#   10296 # indices will always be np.ndarray since axis is not None and
#   10297 # values is a 2d array for DataFrame
#   10298 # error: Item "int" of "Union[int, Any]" has no attribute "__iter__"
#
# ...

# %%
my_df = df [['linea', 'sentido', 'tipodia']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 my_df = df [['linea', 'sentido', 'tipodia']]
#
# NameError: name 'df' is not defined

# %%
df = my_df [['linea', 'sentido', 'tipodia']]

# %%
df_max = df.groupby(['linea']).max

# %%
print (df_max)

# %%
df_max = df.groupby(['linea']).max

# %%
print (df_max)
# Out:
# <bound method GroupBy.max of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x00000245796419C0>>

# %%
df = my_df [['linea', 'sentido', 'tipodia', 'trayecto']]

# %%
df_g =df.groupby(['linea']).count()

# %%
print (df_g)
# Out:
#        sentido  tipodia  trayecto
# linea
# 1          100      100       100
# 2           20       20        20
# 4           10       10        10
# 6           30       30        30
# 7           50       50        50
# 8           40       40        40
# 9           50       50        50
# 10          30       30        30
# 11          20       20        20
# 12          50       50        50
# 14          20       20        20
# 15          10       10        10
# 18          10       10        10
# 19          10       10        10
# 21          40       40        40
# 26          30       30        30
# 27          40       40        40
# 28          50       50        50
# 32          20       20        20
# 33          40       40        40
# 39          20       20        20
# 40          53       53        53
# 41          20       20        20
# 43          40       40        40
# 45          70       70        70
# 47          10       10        10
# ...
